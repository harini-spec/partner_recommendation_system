# %%
import pandas as pd
from scipy.spatial import distance

# %%
df = pd.read_csv("student_partner.csv")
df.head(10)
# Out:
#    id first_name   last_name  age  gender                        email  \
# 0   1     Coleen    Butteris   23  Female     cbutteris0@homestead.com
# 1   2     Merell     Brixham   18    Male             mbrixham1@qq.com
# 2   3      Bevan  Hirsthouse   28    Male  bhirsthouse2@mayoclinic.com
# 3   4      Bunni      Franca   26  Female            bfranca3@furl.net
# 4   5  Annabella  Signorelli   28  Female      asignorelli4@rediff.com
# 5   6      Angel         Tal   21  Female                atal5@psu.edu
# 6   7    Beatrix    Gibbeson   30  Female      bgibbeson6@blogspot.com
# 7   8     Oberon      Ladell   29    Male            oladell7@1688.com
# 8   9     Wolfie      Hinken   29    Male          whinken8@sphinn.com
# 9  10        Ado    Seelbach   24    Male   aseelbach9@theatlantic.com
#
#          language       linkedin_skills  linkedin_act  github_act  \
# 0       Afrikaans           Short Sales             2           7
# 1       Bulgarian         Underscore.js             9           3
# 2  Northern Sotho                  Xing             9           6
# 3         Bislama              3Com NBX             9           4
# 4        Albanian      BTS Installation             6           7
# 5            Zulu                PET-CT             5           3
# 6      Belarusian      Accounts Payable             8           4
# 7      Portuguese               Theatre             9           5
# 8         Yiddish  Interpersonal Skills             9          10
# 9         Punjabi         Type Approval             6           8
#
#    paper_published
# 0               10
# 1                7
# 2                2
# 3                6
# 4                4
# 5                7
# 6                7
# 7                1
# 8               10
# 9                5

# %%
df. drop("last_name", axis=1, inplace=True)
df. drop("linkedin_skills", axis=1, inplace=True)

# %%
df.fillna(round(df.mean()), inplace=True)
# Out:
# /tmp/ipykernel_9794/1934150901.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(round(df.mean()), inplace=True)

# %%
df = df.rename(columns={'first_name': 'name'})

# %%
df.head()
# Out:
#    id       name  age  gender                        email        language  \
# 0   1     Coleen   23  Female     cbutteris0@homestead.com       Afrikaans
# 1   2     Merell   18    Male             mbrixham1@qq.com       Bulgarian
# 2   3      Bevan   28    Male  bhirsthouse2@mayoclinic.com  Northern Sotho
# 3   4      Bunni   26  Female            bfranca3@furl.net         Bislama
# 4   5  Annabella   28  Female      asignorelli4@rediff.com        Albanian
#
#    linkedin_act  github_act  paper_published
# 0             2           7               10
# 1             9           3                7
# 2             9           6                2
# 3             9           4                6
# 4             6           7                4

# %%
int_list = ['Machine Learning','Artificial Intelligence', 'Data Science', 'Web - Front end', 'Web - Back end', 'Web - Full stack', 'Competitive programming']
interest = []
import random
for i in range(1000):
    num = random.randrange(7)
    interest.append(int_list[num])

# %%
df["interest"] = interest

# %%
# interest
df
# Out:
#        id       name  age  gender                            email  \
# 0       1     Coleen   23  Female         cbutteris0@homestead.com
# 1       2     Merell   18    Male                 mbrixham1@qq.com
# 2       3      Bevan   28    Male      bhirsthouse2@mayoclinic.com
# 3       4      Bunni   26  Female                bfranca3@furl.net
# 4       5  Annabella   28  Female          asignorelli4@rediff.com
# ..    ...        ...  ...     ...                              ...
# 995   996  Annemarie   23  Female               abuckamrn@dell.com
# 996   997      Willi   18    Male            wciccoloiro@ifeng.com
# 997   998     Dianne   29  Female  dhagerghamrp@barnesandnoble.com
# 998   999   Alistair   20    Male               asloamrq@google.fr
# 999  1000    Shelden   26    Male     shulksrr@businessinsider.com
#
#            language  linkedin_act  github_act  paper_published  \
# 0         Afrikaans             2           7               10
# 1         Bulgarian             9           3                7
# 2    Northern Sotho             9           6                2
# 3           Bislama             9           4                6
# 4          Albanian             6           7                4
# ..              ...           ...         ...              ...
# 995    West Frisian             1           8                2
# 996        Romanian             9           6               10
# 997           Dutch             7           5                8
# 998         Burmese            10           2                8
# 999           Malay             2           3                1
#
#                     interest
# 0            Web - Front end
# 1               Data Science
# 2               Data Science
# 3           Machine Learning
# 4            Web - Front end
# ..                       ...
# 995  Artificial Intelligence
# 996         Machine Learning
# 997           Web - Back end
# 998  Competitive programming
# 999             Data Science
#
# [1000 rows x 10 columns]

# %%
df.to_csv("learning_partner.csv", index=False)

# %%
# address = ['Delhi', 'Bangalore', 'Chennai', 'Patna']
# df['Address'] = address
# print(df)

# %%
def find_top_similar_entitties(max, nba, distance_frame, primary_column, sec_col):
    
    similar_list = []

    for i in range(max):
    
        current_farthest = distance_frame.iloc[i]["idx"]
        close_to_the_top_founder = nba.loc[int(current_farthest)][primary_column]
        mail = nba.loc[int(current_farthest)][sec_col]

        current_distance = distance_frame.iloc[i]["dist"]
        percentile = 100 - (100 / 18.9714833602) * current_distance
        
        current_distance = round(current_distance, 2)
    
        if percentile <0:
            percentile = 0 
            
        percentile = round(percentile, 2)    

        print('similar '+str(i)+' : '+str(close_to_the_top_founder) + ', email : ' +str(mail) + ", Similarity Percentile : "+ (str(percentile)))

        current_user = {
            "name" : str(close_to_the_top_founder),
            "email" : str(mail),
            "similarity percentile" : percentile
        }

        similar_list.append(current_user)

    return similar_list

# %%
given_entity_name = "Coleen"

# %%
selected_student = df[df["name"] == given_entity_name].iloc[0]
selected_student
# Out:
# id                                        1
# name                                 Coleen
# age                                      23
# gender                               Female
# email              cbutteris0@homestead.com
# language                          Afrikaans
# linkedin_act                              2
# github_act                                7
# paper_published                          10
# interest                    Web - Front end
# Name: 0, dtype: object

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()
le.fit(df["gender"])
df["gender"] = le.transform(df["gender"])

# %%
df.head()
# Out:
#    id       name  age  gender                        email        language  \
# 0   1     Coleen   23       0     cbutteris0@homestead.com       Afrikaans
# 1   2     Merell   18       1             mbrixham1@qq.com       Bulgarian
# 2   3      Bevan   28       1  bhirsthouse2@mayoclinic.com  Northern Sotho
# 3   4      Bunni   26       0            bfranca3@furl.net         Bislama
# 4   5  Annabella   28       0      asignorelli4@rediff.com        Albanian
#
#    linkedin_act  github_act  paper_published          interest
# 0             2           7               10   Web - Front end
# 1             9           3                7      Data Science
# 2             9           6                2      Data Science
# 3             9           4                6  Machine Learning
# 4             6           7                4   Web - Front end

# %%
le.fit(df["language"])
df["language"] = le.transform(df["language"])

# %%
df["language"].values
# Out:
# array([ 0, 12, 69, 10,  1, 96,  8, 76, 95, 77, 38, 96,  0, 53, 44, 52, 90,
#        76, 12, 80, 27, 84, 77, 67, 17, 30, 15, 48, 68, 57, 30, 26, 86, 27,
#        80, 55, 62, 30,  7, 54, 35, 74, 72,  8, 54, 59, 88, 80, 87, 92,  2,
#        88,  8, 35, 84, 30,  0, 40, 81, 70,  0, 52, 33, 81, 59, 36, 63, 26,
#        54, 31, 29, 71, 95,  3, 70,  3, 31, 19, 37, 38, 85, 96, 33, 89,  4,
#        45, 83,  1, 24, 35, 37,  4,  1, 40, 87, 55, 81, 38, 47, 47,  3, 89,
#        82, 28,  2, 49, 21, 17, 52, 10, 22, 80, 59,  4, 28, 26, 96, 66, 84,
#        35, 46, 41, 24, 54, 86, 58, 50,  1, 36, 33, 81, 20, 25, 39, 74,  9,
#         3, 59, 79, 15, 71, 67, 13, 58, 46, 57, 20, 35, 51, 55, 96, 18,  0,
#        71, 56, 94, 65, 85, 57, 72, 32,  1,  9, 69, 54, 13, 55, 19, 75, 46,
#        90,  5, 30, 32, 92,  2, 58,  1, 27, 10, 82, 61, 90, 11, 62, 72, 62,
#        69, 45,  9, 73, 43, 21, 89, 47, 18,  5, 66, 69, 96, 22, 51, 67,  8,
#         3, 89,  3, 61,  5, 18, 27, 27, 44, 54, 44, 19, 89, 19, 95, 16, 13,
#        17, 27,  0, 39, 39, 39, 54, 27, 57, 36, 34, 71, 53,  1, 61, 87,  2,
#        95, 10, 77,  6, 92, 26, 22, 96, 90, 49, 86, 37, 76, 27, 29, 18, 12,
#        40, 55, 65,  4, 10, 76, 55, 92, 59, 68, 43, 78, 78,  2, 27, 64,  3,
#        30, 48, 66, 46, 51, 42, 62, 32, 48, 53, 12, 32,  7,  7, 31, 66, 15,
#        52, 16, 61, 31, 50, 64, 15, 30, 66, 56, 71, 81, 18, 41, 55, 47, 41,
#        29, 76, 60, 86, 64, 93, 83, 45, 85, 86, 49, 96, 61, 63, 92, 46, 74,
#        68, 42, 65, 85, 24,  9, 49, 56, 51, 23, 86, 38, 56, 92, 25, 58,  5,
#        48, 18, 42, 35, 56, 16, 77,  0, 78, 82, 49, 84, 38, 27, 40, 15, 86,
#        32,  6, 74, 67, 57, 51, 91, 19, 20, 57, 31, 39, 18, 54, 50, 13, 82,
#        85, 22, 79, 25, 74, 64, 29, 12,  2, 72, 40, 94, 48, 58, 62,  5, 75,
#        27, 89,  9, 60, 14, 80, 53, 89, 74, 11, 72, 38, 48,  4, 50, 57,  6,
#        28, 22, 64, 90, 92, 75, 33, 70, 76, 67,  1, 48, 85, 57, 80, 65, 88,
#        63, 37, 77, 73,  2, 42, 85, 72, 40, 30, 16, 49, 51, 79, 27, 95, 33,
#        18, 12, 15, 72, 74, 30, 72, 96, 95, 71, 24, 55, 40, 29,  7, 76, 40,
#         4, 20, 87, 23, 31,  8, 88, 75, 78, 94, 79, 21, 13, 58])

# %%
df.head()
# Out:
#    id       name  age  gender                        email  language  \
# 0   1     Coleen   23       0     cbutteris0@homestead.com         0
# 1   2     Merell   18       1             mbrixham1@qq.com        12
# 2   3      Bevan   28       1  bhirsthouse2@mayoclinic.com        69
# 3   4      Bunni   26       0            bfranca3@furl.net        10
# 4   5  Annabella   28       0      asignorelli4@rediff.com         1
#
#    linkedin_act  github_act  paper_published          interest
# 0             2           7               10   Web - Front end
# 1             9           3                7      Data Science
# 2             9           6                2      Data Science
# 3             9           4                6  Machine Learning
# 4             6           7                4   Web - Front end

# %%
df.columns
# Out:
# Index(['id', 'name', 'age', 'gender', 'email', 'language', 'linkedin_act',
#        'github_act', 'paper_published', 'interest'],
#       dtype='object')

# %%
columns = ['age', 'linkedin_act', 'github_act', 'paper_published', 'gender', 'language']

# %%
nba_numeric = df[columns]

# %%
nba_normalized = (nba_numeric - nba_numeric.mean()) / nba_numeric.std()

# %%
nba_normalized.fillna(round(nba_normalized.mean()), inplace=True)
nba_normalized
# Out:
#           age  linkedin_act  github_act  paper_published  gender  language
# 0    0.032517     -1.187657    0.484847         1.523496 -0.9995 -1.690217
# 1   -1.104437      1.204057   -0.902412         0.487574  0.9995 -1.264987
# 2    1.169471      1.204057    0.138032        -1.238963  0.9995  0.754853
# 3    0.714689      1.204057   -0.555597         0.142267 -0.9995 -1.335859
# 4    1.169471      0.179037    0.484847        -0.548348 -0.9995 -1.654781
# ..        ...           ...         ...              ...     ...       ...
# 995  0.032517     -1.529330    0.831661        -1.238963 -0.9995  1.640748
# 996 -1.104437      1.204057    0.138032         1.523496  0.9995  1.109211
# 997  1.396862      0.520710   -0.208782         0.832882 -0.9995 -0.946065
# 998 -0.649656      1.545731   -1.249226         0.832882  0.9995 -1.229551
# 999  0.714689     -1.187657   -0.902412        -1.584271  0.9995  0.365060
#
# [1000 rows x 6 columns]

# %%
# nba_normalized["language"]

# %%
# count = 1
# for i in nba_normalized["language"]:
#     if(i==-1.6902167658157476):
#         print(count)
#     count=count+1

# %%
top_founder_normalized = nba_normalized[df["name"] == given_entity_name]
top_founder_normalized
# Out:
#         age  linkedin_act  github_act  paper_published  gender  language
# 0  0.032517     -1.187657    0.484847         1.523496 -0.9995 -1.690217

# %%
# distances = nba_normalized.apply(lambda row: distance.canberra(row, top_founder_normalized.iloc[0]), axis=1)
distances = nba_normalized.apply(lambda row: distance.braycurtis(row, top_founder_normalized.iloc[0]), axis=1)
# distances = nba_normalized.apply(lambda row: distance.chebyshev(row, top_founder_normalized.iloc[0]), axis=1)
# distances = nba_normalized.apply(lambda row: distance.cosine(row, top_founder_normalized.iloc[0]), axis=1)
# distances = nba_normalized.apply(lambda row: distance.euclidean(row, top_founder_normalized.iloc[0]), axis=1)
# distances = nba_normalized.apply(lambda row: distance.minkowski(row, top_founder_normalized.iloc[0], p=1), axis=1)
# distances = nba_normalized.apply(lambda row: distance.minkowski(row, top_founder_normalized.iloc[0], p=3), axis=1)

# %%
distance_frame = pd.DataFrame(data={"dist": distances, "idx": distances.index})

# %%
distance_frame
# Out:
#          dist  idx
# 0    0.000000    0
# 1    1.294170    1
# 2    3.620196    2
# 3    0.777378    3
# 4    0.485389    4
# ..        ...  ...
# 995  1.054479  995
# 996  1.624572  996
# 997  0.555434  997
# 998  1.183042  998
# 999  1.874024  999
#
# [1000 rows x 2 columns]

# %%
distance_frame.sort_values(by=["dist"], inplace=True)

# %%
second_smallest = distance_frame.iloc[1]["idx"]
most_nearer_entity = df.loc[int(second_smallest)]["name"]

# %%
print('Direct similarity : '+most_nearer_entity)
# Out:
# Direct similarity : Danell

# %%
print('\nTop 4 developers Sorted')
similar_5_list = find_top_similar_entitties(5, df, distance_frame, "name", "email")
# Out:
# Top 4 developers Sorted
# similar 0 : Coleen, email : cbutteris0@homestead.com, Similarity Percentile : 100.0
# similar 1 : Danell, email : ddimberline2a@jiathis.com, Similarity Percentile : 99.27
# similar 2 : Gerhardine, email : gaspden2c@1688.com, Similarity Percentile : 99.22
# similar 3 : Jasmina, email : jbaggettev@nymag.com, Similarity Percentile : 99.21
# similar 4 : Libbie, email : lboole77@time.com, Similarity Percentile : 99.12
